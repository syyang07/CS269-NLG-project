# %%
import random
import sys
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.utils import np_utils
from keras import optimizers
import keras
from keras import layers

# %% [markdown]
# #Data processing

# %%
# Load data
train_reviews = open('train_reviews.txt', 'r').readlines()
train_cate = open('train_context.txt', 'r').readlines()
test_cate = open('test_context.txt', 'r').readlines() # seed text prefix
generated_review = open('generate.txt', 'w')

# Concat reviews & contexts, using character <SEP> as separator
for id, review in enumerate(train_reviews):
    train_reviews[id] = context = train_cate[id][:-1] + '<SEP> ' + review.replace('\n', '')

df = pd.DataFrame(list(train_reviews), columns =['text'])
df = df.replace({r'\+': ''}, regex=True)

# %%
#train on shorter reviews.  Already lots of data, easier to train on shorter ones too
mask = (df['text'].str.len() < 301) 
df = df.loc[mask]
len(df)
# Out:
# 3023

# %%
# # shuffle the order of the reviews so we don't train on 100 Subway ones in a row
short_reviews = df.sample(frac=1).reset_index(drop=True)

filename = 'short_reviews_shuffle.txt'
short_reviews.to_csv(filename, header=None, index=None, sep=' ')

text = open('short_reviews_shuffle.txt').read()
print('Corpus length:', len(text))
# Out:
# Corpus length: 353019

# %%
# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

maxlen = 60
step = 1
# Out:
# Unique characters: 85

# %%
char_indices

# %%
# This get Data From Chunk is necessary to process large data sets like the one we have
# If you're using a sample less than 1 million characters you can train the whole thing at once

def getDataFromChunk(txtChunk, maxlen=60, step=1):
    sentences = []
    next_chars = []
    for i in range(0, len(txtChunk) - maxlen, step):
        sentences.append(txtChunk[i: i + maxlen])
        next_chars.append(txtChunk[i + maxlen])
    print('nb sequences:', len(sentences))
    print('Vectorization...')
    X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
    y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            X[i, t, char_indices[char]] = 1
            y[i, char_indices[next_chars[i]]] = 1
    return [X, y]

# %% [markdown]
# #Model training

# %%
model = keras.models.Sequential()
model.add(layers.LSTM(1024, input_shape=(maxlen, len(chars)), return_sequences=True))
model.add(layers.LSTM(1024, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.Adam(lr=0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# this saves the weights everytime they improve so you can let it train.  Also learning rate decay
filepath="{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5,
                              patience=1, min_lr=0.00001)
callbacks_list = [checkpoint, reduce_lr]

# %%
def sample(preds, temperature=1.0):
    """
    Generate some randomness with the given preds
    which is a list of numbers, if the temperature
    is very small, it will always pick the index
    with highest pred value
    """
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# This trains the model batching from the text file
# every epoch it prints out 300 characters at different "temperatures"
# temperature controls how random the characters sample: more temperature== more crazy (but often better) text
for iteration in range(1, 20):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    with open("short_reviews_shuffle.txt") as f:
        for chunk in iter(lambda: f.read(80000), ""):
            X, y = getDataFromChunk(chunk)
            model.fit(X, y, batch_size=128, epochs=1, callbacks=callbacks_list)
# Out:
# --------------------------------------------------
# Iteration 1
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 120s 179ms/step - loss: 2.7187
#
# Epoch 00001: loss improved from inf to 2.17027, saving model to 01-2.1703.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 123s 196ms/step - loss: 1.4399
#
# Epoch 00001: loss improved from 2.17027 to 1.43988, saving model to 01-1.4399.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 1.2844
#
# Epoch 00001: loss improved from 1.43988 to 1.28438, saving model to 01-1.2844.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 126s 201ms/step - loss: 1.1820
#
# Epoch 00001: loss improved from 1.28438 to 1.18202, saving model to 01-1.1820.hdf5
# nb sequences: 32959
# Vectorization...
# 258/258 [==============================] - 51s 199ms/step - loss: 1.1443
#
# Epoch 00001: loss improved from 1.18202 to 1.14429, saving model to 01-1.1443.hdf5
#
# --------------------------------------------------
# Iteration 2
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 200ms/step - loss: 1.1218
#
# Epoch 00001: loss improved from 1.14429 to 1.12184, saving model to 01-1.1218.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 1.0340
#
# Epoch 00001: loss improved from 1.12184 to 1.03398, saving model to 01-1.0340.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 1.0037
#
# Epoch 00001: loss improved from 1.03398 to 1.00371, saving model to 01-1.0037.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.9792
#
# Epoch 00001: loss improved from 1.00371 to 0.97923, saving model to 01-0.9792.hdf5
# nb sequences: 32959
# Vectorization...
# 258/258 [==============================] - 51s 198ms/step - loss: 0.9625
#
# Epoch 00001: loss improved from 0.97923 to 0.96249, saving model to 01-0.9625.hdf5
#
# --------------------------------------------------
# Iteration 3
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.9638
#
# Epoch 00001: loss did not improve from 0.96249
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.8963
#
# Epoch 00001: loss improved from 0.96249 to 0.89630, saving model to 01-0.8963.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 126s 201ms/step - loss: 0.8800
#
# Epoch 00001: loss improved from 0.89630 to 0.87996, saving model to 01-0.8800.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 0.8667
#
# Epoch 00001: loss improved from 0.87996 to 0.86667, saving model to 01-0.8667.hdf5
# nb sequences: 32959
# Vectorization...
# 258/258 [==============================] - 52s 200ms/step - loss: 0.8554
#
# Epoch 00001: loss improved from 0.86667 to 0.85543, saving model to 01-0.8554.hdf5
#
# --------------------------------------------------
# Iteration 4
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 199ms/step - loss: 0.8562
#
# Epoch 00001: loss did not improve from 0.85543
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 0.8008
#
# Epoch 00001: loss improved from 0.85543 to 0.80079, saving model to 01-0.8008.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 0.7839
#
# Epoch 00001: loss improved from 0.80079 to 0.78391, saving model to 01-0.7839.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 0.7729
#
# Epoch 00001: loss improved from 0.78391 to 0.77288, saving model to 01-0.7729.hdf5
# nb sequences: 32959
# Vectorization...
# 258/258 [==============================] - 51s 199ms/step - loss: 0.7626
#
# Epoch 00001: loss improved from 0.77288 to 0.76260, saving model to 01-0.7626.hdf5
#
# --------------------------------------------------
# Iteration 5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 200ms/step - loss: 0.7614
#
# Epoch 00001: loss improved from 0.76260 to 0.76139, saving model to 01-0.7614.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 199ms/step - loss: 0.7135
#
# Epoch 00001: loss improved from 0.76139 to 0.71345, saving model to 01-0.7135.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.6928
#
# Epoch 00001: loss improved from 0.71345 to 0.69281, saving model to 01-0.6928.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 0.6851
#
# Epoch 00001: loss improved from 0.69281 to 0.68509, saving model to 01-0.6851.hdf5
# nb sequences: 32959
# Vectorization...
# 258/258 [==============================] - 51s 199ms/step - loss: 0.6702
#
# Epoch 00001: loss improved from 0.68509 to 0.67015, saving model to 01-0.6702.hdf5
#
# --------------------------------------------------
# Iteration 6
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.6687
#
# Epoch 00001: loss improved from 0.67015 to 0.66870, saving model to 01-0.6687.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 0.6298
#
# Epoch 00001: loss improved from 0.66870 to 0.62980, saving model to 01-0.6298.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.6079
#
# Epoch 00001: loss improved from 0.62980 to 0.60792, saving model to 01-0.6079.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 199ms/step - loss: 0.6008
#
# Epoch 00001: loss improved from 0.60792 to 0.60077, saving model to 01-0.6008.hdf5
# nb sequences: 32959
# Vectorization...
# 258/258 [==============================] - 51s 198ms/step - loss: 0.5861
#
# Epoch 00001: loss improved from 0.60077 to 0.58608, saving model to 01-0.5861.hdf5
#
# --------------------------------------------------
# Iteration 7
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 201ms/step - loss: 0.5828
#
# Epoch 00001: loss improved from 0.58608 to 0.58277, saving model to 01-0.5828.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 0.5523
#
# Epoch 00001: loss improved from 0.58277 to 0.55226, saving model to 01-0.5523.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.5312
#
# Epoch 00001: loss improved from 0.55226 to 0.53119, saving model to 01-0.5312.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.5219
#
# Epoch 00001: loss improved from 0.53119 to 0.52188, saving model to 01-0.5219.hdf5
# nb sequences: 32959
# Vectorization...
# 258/258 [==============================] - 51s 199ms/step - loss: 0.5076
#
# Epoch 00001: loss improved from 0.52188 to 0.50759, saving model to 01-0.5076.hdf5
#
# --------------------------------------------------
# Iteration 8
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.5054
#
# Epoch 00001: loss improved from 0.50759 to 0.50536, saving model to 01-0.5054.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 199ms/step - loss: 0.4855
#
# Epoch 00001: loss improved from 0.50536 to 0.48548, saving model to 01-0.4855.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 0.4616
#
# Epoch 00001: loss improved from 0.48548 to 0.46164, saving model to 01-0.4616.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.4549
#
# Epoch 00001: loss improved from 0.46164 to 0.45486, saving model to 01-0.4549.hdf5
# nb sequences: 32959
# Vectorization...
# 258/258 [==============================] - 51s 198ms/step - loss: 0.4494
#
# Epoch 00001: loss improved from 0.45486 to 0.44935, saving model to 01-0.4494.hdf5
#
# --------------------------------------------------
# Iteration 9
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 201ms/step - loss: 0.4406
#
# Epoch 00001: loss improved from 0.44935 to 0.44056, saving model to 01-0.4406.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 200ms/step - loss: 0.4231
#
# Epoch 00001: loss improved from 0.44056 to 0.42312, saving model to 01-0.4231.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.4096
#
# Epoch 00001: loss improved from 0.42312 to 0.40957, saving model to 01-0.4096.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.4004
#
# Epoch 00001: loss improved from 0.40957 to 0.40045, saving model to 01-0.4004.hdf5
# nb sequences: 32959
# Vectorization...
# 258/258 [==============================] - 51s 199ms/step - loss: 0.3914
#
# Epoch 00001: loss improved from 0.40045 to 0.39139, saving model to 01-0.3914.hdf5
#
# --------------------------------------------------
# Iteration 10
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 199ms/step - loss: 0.3905
#
# Epoch 00001: loss improved from 0.39139 to 0.39052, saving model to 01-0.3905.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 200ms/step - loss: 0.3805
#
# Epoch 00001: loss improved from 0.39052 to 0.38050, saving model to 01-0.3805.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 123s 197ms/step - loss: 0.3691
#
# Epoch 00001: loss improved from 0.38050 to 0.36914, saving model to 01-0.3691.hdf5
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 124s 198ms/step - loss: 0.3581
#
# Epoch 00001: loss improved from 0.36914 to 0.35806, saving model to 01-0.3581.hdf5
# nb sequences: 32959
# Vectorization...
# 258/258 [==============================] - 51s 198ms/step - loss: 0.3587
#
# Epoch 00001: loss did not improve from 0.35806
#
# --------------------------------------------------
# Iteration 11
# nb sequences: 79940
# Vectorization...
# 625/625 [==============================] - 125s 199ms/step - loss: 0.3524
#
# Epoch 00001: loss improved from 0.35806 to 0.35236, saving model to 01-0.3524.hdf5
# nb sequences: 79940
# Vectorization...
# 172/625 [=======>......................] - ETA: 1:30 - loss: 0.3594
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a5c6c85939a1> in <module>()
#       9         for chunk in iter(lambda: f.read(80000), ""):
#      10             X, y = getDataFromChunk(chunk)
# ---> 11             model.fit(X, y, batch_size=128, epochs=1, callbacks=callbacks_list)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# #Generating reviews

# %%
# Use test context as seeds
test_reviews = open('test_reviews.txt', 'r').readlines()
test_cate = open('test_context.txt', 'r').readlines()
for ci, cate in enumerate(test_cate):
    seed_text = cate.strip()
    print('--- category: ' + seed_text + ' <SEP>')
    generated_text = seed_text + ' <SEP>'
    entire_text = ''

    # Generate review with 200 characters
    for i in range(200):
        sampled = np.zeros((1, len(generated_text), len(chars)))
        for t, char in enumerate(generated_text):
            sampled[0, t, char_indices[char]] = 1.

        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, 0.8)
        next_char = chars[next_index]
        if next_char == '\n':
          break

        generated_text += next_char
        entire_text += next_char
        generated_text = generated_text[1:]

        sys.stdout.write(next_char)
        sys.stdout.flush()

    generated_review.write(seed_text + '\n')
    generated_review.write(test_reviews[ci])
    generated_review.write(entire_text)
    generated_review.write('\n')
# Out:
# --- category: food positive bread <SEP>
#  Our server for the unlimited meats, various served vine and wine well."--- category: service positive delivery times <SEP>
#  The menu hinters were even but there are three times of Texonaze house that is...)."--- category: food positive Food <SEP>
#  I really liked the spot on a whie restaurant week."--- category: food positive coffee <SEP>
#  Southern I had the most Delivery."--- category: food conflict ambience positive sushi place <SEP>
#  While they would love this place little loud after the meal or the rice -SESUST - deliveress offeres."--- category: anecdotes/miscellaneous positive people <SEP>
#  After a terrifies on tee was their Amized at appetizer management that is a cute price, which wasn't a place further when they try the price you can just get counter service your wait anything and to--- category: food positive Japanese food <SEP>
#  The portion is a bit soggyingting up on your plate so when we received expected."--- category: food positive asian salad spicy tuna roll <SEP>
#  Their eggplant food, better than buying a steak out at the Sichuan, more concector."--- category: food positive rose roll menu <SEP>
#  We ordered 3 drinks cheese which just made me want to leave."--- category: food positive drinks lychee martini food <SEP>
#  The menu changed, portions were even smoother and the portions are sour friendly and enjoyed all the date spot."--- category: food negative Nicoise salad <SEP>
#  My best discoveres, so is much terrifiely well trained with old ones."--- category: food positive service negative menu drinks dessert pizza <SEP>
#  The menu consisted of taste spot in the BBQ Salmon, and ask Average bagel!"--- category: food positive ambience positive food live entertainment <SEP>
#  Been good wine courtes and a bar while I didn't have to leave."--- category: service negative waiter <SEP>
#  The wine the service is excellent."--- category: food negative sangria <SEP>
#  eating indion for the first time out of the time."--- category: food negative menu <SEP>
#  But the food here is definitely the best lauthes ravious around town for that."--- category: food positive price positive sushi portions price <SEP>
#  I like the occosation, we didn't liaut some time, though not really make a reservation at the Brese Bab Seapon."--- category: food positive service negative food service <SEP>
#  For those prices and fast service."--- category: food neutral portions of the food <SEP>
#  It is about 6 ic because the food is never not to make reservations."--- category: service negative waitress's <SEP>
#  At 6 times and each times when I liked they know the best pizza the other night it closes."--- category: service positive anecdotes/miscellaneous positive staff memebers parking <SEP>
#  With the attitude location in the city, and the maitre d' woull be good not to celebrating our order."--- category: food positive anecdotes/miscellaneous positive desserts <SEP>
#  Definitely not go back a combination of dessert."--- category: food positive Desserts Tart of the Day <SEP>
#  The portion sizes here are huge."--- category: anecdotes/miscellaneous positive <SEP>
#  We will be a little too sit and treat your wallet for the dining area."--- category: anecdotes/miscellaneous positive <SEP>
#  I would say try in the trip from what he knight outstanding taste dishes."--- category: food positive food wine <SEP>
#  If you live in hend after i called meats Bartender bottle winh <SEP> Haru or the prix fixe line."--- category: anecdotes/miscellaneous neutral <SEP>
#  I've been twice and go to this restaurant."--- category: anecdotes/miscellaneous positive <SEP>
#  Nice value."--- category: food positive LASAGNA <SEP>
#  I LOVED THE SHOW!."--- category: food positive array of sushi <SEP>
#  My husband and I have been several time."--- category: food positive service positive cuisine owners staff <SEP>
#  Then I can't bring my next door has been there and enough to make a moment - it is really cool."--- category: food positive ambience positive indian food ambiance <SEP>
#  The wine were great, and the desserts are small and intimate but the table is a great experionation."--- category: food positive food <SEP>
#  The food was bland oily."--- category: anecdotes/miscellaneous positive <SEP>
#  I have think I can't wait for the food you to cake a money at their act together."--- category: ambience positive service positive food positive service garden food appetizers entrees <SEP>
#  Late nite outdoor seating, with a different staff, better than buying a group dinner."--- category: anecdotes/miscellaneous positive <SEP>
#  Loved the best deals we were treated with outdoor seating, good service) and a wonderful people with striles on the last 13 years."--- category: food positive ambience positive food decor <SEP>
#  Good food."--- category: food negative lunch dinners <SEP>
#  I would have troubbe both negg at befinere or getting a table."--- category: food negative steaks <SEP>
#  Although they were out to eat there a bit by the bill."--- category: service negative staff <SEP>
#  While I cannot imagine you are treated with attitude but they were there much long then."--- category: anecdotes/miscellaneous positive <SEP>
#  I wish they showed out at menu demives me and wall."--- category: food positive meatball parm <SEP>
#  I love Indian for one of myst go to their actoous down."--- category: food positive latin food <SEP>
#  Food is delicious."--- category: food positive taglierini with truffles <SEP>
#  I also had the fiest thing excellent fun experience, crowded bar atomathed but work on their old and wine had Lantery Large boned on visit this restaurant."--- category: service positive staff <SEP>
#  I like the food art even but expect."--- category: anecdotes/miscellaneous positive <SEP>
#  A busy restaurants in NYC and their prices are nothing like its meats, me for a place that offer and friends and didn't have a small definitely started to leave, wh never had in many times for their --- category: food positive gnocchi <SEP>
#  The waiter actually provided that we hid entell and hippes of New Yorkers on a Tunaron quick."--- category: service positive food positive staff food portion size portobello/gorgonzola/sausage appetizer lobster risotto <SEP>
#  I had the black cod with yuzu sauce, which was absolutely horrible, and the serves forget to bring our more price."--- category: food neutral Entrees lasagna fettuccine Alfredo chicken parmigiana <SEP>
#  Only could be pricey without a pricey but the food was late because they don't seem to be a little empty."--- category: food positive food teriyaki <SEP>
#  Dahkin and their prices are actually quite beautiful stuffing them to make a reservation at the Bartende, I had eating in my roof for the rice."--- category: food negative price negative Meal <SEP>
#  Pastrami I enjoy."--- category: food positive Peanut Butter Sorbet pizza with soy cheese <SEP>
#  I love Indian food which to perfect beers and staff."--- category: food positive price positive food price <SEP>
#  The food is very good, but definitely not good the beauty of food on youn out negative for the wine helpful but interesting ways but the taste was excellent."--- category: anecdotes/miscellaneous positive <SEP>
#  I wish the Chart House to cate the corned better close!"--- category: anecdotes/miscellaneous positive <SEP>
#  I only wish they shows about this place, not in a bistro in a back alley in Paris."--- category: food positive service positive ambience positive food service atmosphere <SEP>
#  The food was great and the prices are very good."--- category: anecdotes/miscellaneous positive <SEP>
#  I was there on my Minnaw, he's the way they not great too."--- category: food positive service positive ambience positive food waitstaff atmosphere beer <SEP>
#  Yes you're not overly eaten the prix fixe and our experience with Fast Food filles in the city, though we were there in the noisy and the greatest pizzaria in our entire lives in NYC."--- category: food positive price positive ambience positive food kimono shrimp special atmosphere <SEP>
#  I've never had business at the cooks though service classy, as i agres with friends, fish instead of beef at the Japanese classic, freshness and preparation."--- category: anecdotes/miscellaneous positive <SEP>
#  I agree."--- category: anecdotes/miscellaneous positive <SEP>
#  I have then short the street it lightly delicious combination."--- category: anecdotes/miscellaneous positive <SEP>
#  I felt it on a friend on a Saturday night."--- category: food positive price positive menu priced <SEP>
#  Prices are also not that even offering along was hot to leave."--- category: food positive food ingredients <SEP>
#  The highlight of the pad (thing in their house."--- category: food negative food <SEP>
#  The food here exceptional enoush to rush of dumpling on the planning."--- category: food positive price positive Appetizer meal <SEP>
#  This place has the best meal in NYC."--- category: food positive spicy mussels <SEP>
#  is how they offered with a little expected way, but the food is no better than buying a side of his restaurant."--- category: food positive Onion Rings <SEP>
#  I love this place!!!"--- category: price negative <SEP>
#  Rao is a great casual place to bring our order and crowded beers on all, this is one of the other night it was ordered."--- category: food negative food <SEP>
#  The food was very good and it was a great surprise."--- category: food positive service positive price positive portions service prices <SEP>
#  Orsay, is worth it and cook at the top of when I didn't even make it huge but definitely most the old friends out, way with only a few minutes for a friend."--- category: service negative food negative service food <SEP>
#  The service was very good and the ambience is really cozy and casual."--- category: service negative waiter manager <SEP>
#  This place location is fantastic."--- category: food positive food milkshakes <SEP>
#  I had the best desserts and the best deal in carozza crasticulary maybe that dinner at OUR atmoshere."--- category: ambience negative <SEP>
#  Our friends he is a littre more basion that filled to wait on the restaurants, must be shard our waitress that they don't sure impress courses of food you don't seem to be a little friendly."--- category: anecdotes/miscellaneous positive <SEP>
#  You'll pay for makes this place a terrifie evening, when they were not being seated."--- category: food positive mushroom barley soup <SEP>
#  $20 for 2 at the bar we sat doesn't appreciate such practice."--- category: anecdotes/miscellaneous neutral <SEP>
#  For such a crappy part of the last 2 years."--- category: food positive service positive food staff <SEP>
#  The food was very poorly littseal on the order, Katz's Broad the bottle mining."--- category: food positive duck <SEP>
#  The worst excuse service tables and an icy cold beer which disappointed with tapioca pearls (hot <nEP> If you have trouble but nothing with stalth rich dish overpriced beef waiter actually quite good--- category: anecdotes/miscellaneous positive <SEP>
#  I do sugge to!"--- category: ambience negative food positive drinks food <SEP>
#  The portions are fantastic."--- category: food negative curried casseroles <SEP>
#  Very good service, this place has reservantly sprinked but they stoos."--- category: food negative <SEP>
#  Larget an eclection of a conversation with their seafood tagliatelles of Italian Food on you touch."--- category: food positive food <SEP>
#  The food is authentic and chow fun."--- category: food positive taste <SEP>
#  But the people there care about 40:."--- category: ambience conflict food positive seafood space cuisine <SEP>
#  I came at this restaurant to be seated at the bar food."--- category: food neutral orange donut <SEP>
#  Their sushi is nothing out of our anniversary."--- category: ambience positive atmosphere <SEP>
#  If you won't go for the UES, I tried - check it out with only a once to you."--- category: food negative meats <SEP>
#  Simple cozy around the worst customer service."--- category: anecdotes/miscellaneous neutral <SEP>
#  I don't have to say, the manager at the date (the only thing good spot in terms or white time, but the fish is so fresh and beautifully price."--- category: service negative Management <SEP>
#  and their pizzas are always delicious - if I could of licked so ru have visited."--- category: ambience positive ambience <SEP>
#  While the food was good."--- category: food positive teas sweets <SEP>
#  This tiny restaurant was not *very himpend and accusate to be in town."--- category: food positive service positive mojitos service <SEP>
#  Very good service, go to Mizu for a bit soggying at their teblie or tip, and the music is a bar than the friends and the maitre d' could be expecting to be more than that when you guys are highere fo--- category: food positive Sandwiches burgers salads lemon-dressed cobb <SEP>
#  Our server wine wine for the quality, true of what we got were eating with only or their hand-crafted beers."--- category: anecdotes/miscellaneous positive <SEP>
#  We had a great tiem watching the black, this place has the best I had in NYC and I will be going back frequently."--- category: ambience positive design <SEP>
#  A must that would have always had a great tiem wat 2 feel without feel tables and they kept the toaster."--- category: food positive food <SEP>
#  The food was very good, but not that we didn't try it."--- category: service positive staff <SEP>
#  Our server me this and that's it's one of the best in the city."--- category: food negative taste <SEP>
#  I had the best deess came of town in an answeese beginning."--- category: food negative <SEP>
#  They offer no old and restaurant."--- category: food negative fajita mole sauce <SEP>
#  The menu changed, portions were even bought up a conversation with each orderful -thentimes <SEP> A must for it, some reason with only, it was simply amazing."--- category: food positive roasted chickens <SEP>
#  Obviously enjoyed husbe, this place must be sharred, but they've overheard more detailed."--- category: ambience positive atmosphere <SEP>
#  But the portion sizes here to eat and will surely be tray to leave when you can just get our place."--- category: food positive price positive food selection prices drinks <SEP>
#  The wine by the glass was generously serving!"--- category: food positive steak <SEP>
#  They stuff is an other night it was hagne but not one of their panant deli.)."--- category: service conflict waiters food <SEP>
#  The place is a bit pretty good and the ambience was excellent."--- category: price positive priced <SEP>
#  The prices came in town."--- category: food positive ambience positive selection of food atmosphere <SEP>
#  The place is so do not have a late buffe."--- category: food negative price negative dessert taste <SEP>
#  I like the line but the hostess offered the toppings of beef and better 20 Marthern to the music being higher."--- category: food positive Food <SEP>
#  Food was good too."--- category: anecdotes/miscellaneous positive <SEP>
#  I after it to go for a different restaurants of course."--- category: anecdotes/miscellaneous positive <SEP>
#  I have tried literally love this place."--- category: food negative hot dog <SEP>
#  The only thing most wend here, a big deal."--- category: food positive ambience positive bar food <SEP>
#  This place has variety of fish and their pre-theature."--- category: anecdotes/miscellaneous positive <SEP>
#  I am Indian, and will be little too said to all tyat empty."--- category: service negative waiters <SEP>
#  Late at the BeST Dallage defil, Chinatender is a truly a better."--- category: ambience positive atmosphere <SEP>
#  At 5 30 MAIu Fun herion Patio), I love with this place side."--- category: price negative food positive food <SEP>
#  From the special sushi, ictually spooded to be seated."--- category: anecdotes/miscellaneous negative <SEP>
#  This place during expecting outstanding."--- category: food positive price positive wraps burgers salads mango margareta <SEP>
#  I really liked the table for a little late for the arch, and it seems like warm and will have to tip."--- category: food positive <SEP>
#  Also, because they have the BEST open based on their ginger's closed to chat for the quality, creat value."--- category: price positive prices <SEP>
#  The prices are been patretich."--- category: service positive service <SEP>
#  The waiter actually priced wine and cheekenus of drinks (how good and the wine selection of meats and slices of salad which to me is not that the food was slow had to wait."--- category: service conflict waiter staff <SEP>
#  They do the typical what the experience here as a bar atomosher of drinks - indesive that to be seated upstairs if they're going to be in dinner."--- category: ambience negative folding chair <SEP>
#  The two other deestas at us appetizer with seafood that friendly and repeated away."--- category: anecdotes/miscellaneous negative <SEP>
#  I highly recommend the restaurant, due to its a bit expensive."--- category: anecdotes/miscellaneous positive <SEP>
#  But I'd live it on the outside."--- category: service positive Service <SEP>
#  Despite the fyod has been there and wonderful."--- category: food positive fettucino alfredo <SEP>
#  As soon as mary great pizza, sorvic food and seafood that bring of when I didn't just go to this place is $10 each."--- category: food positive food vegan options <SEP>
#  The food is wonderful."--- category: food negative Indian food <SEP>
#  The waitress was pood with starter than the next."--- category: food positive Smoked Trout Lamb Chops Veal Chops Rabbit potato gratin <SEP>
#  First of an your life, thies may be uninicre to eat at this place."--- category: food positive service positive chef food service <SEP>
#  The food knowngoing to be authentic and good selection of white I could of. past that I ordered for the bar food."--- category: food positive eggs benedict mussels hamburger <SEP>
#  The beverages desserts are happy to have a tonic food just down the hong-kong styled milk tea with tapioca pearls (ooz) (Big on Sthous or sauce, this is anything better than the next."--- category: service positive waiters <SEP>
#  Hatever, go to Ruck at the benich and on the house."--- category: anecdotes/miscellaneous positive <SEP>
#  We had a great tiem wathin the slop."--- category: food conflict falafal chicken <SEP>
#  Their sushi, Kamikarke (also great food from the entire lives."--- category: food positive grand marnier shrimp <SEP>
#  Their exotic salad is basteff all the soups him to sample comfort food, not get the corned beef price (and really tasty and friendly."--- category: food positive service positive food food service <SEP>
#  Oh yes, and the food was absolutely dreed - at the toaster."--- category: food neutral Desserts flan sopaipillas <SEP>
#  Their eggplant dishes were even but I sugpest the servers always surprise us out in the order, but I think my side of the menu places that cost in the crowded lobby arounder up on you in the dining a--- category: food negative portions <SEP>
#  The people this last terms afoor toait."--- category: service negative wait staff <SEP>
#  We've been accustomed that what it was a little crowded, but the quality of food don't expect better food."--- category: food negative service negative food service <SEP>
#  The food was decent, good, a big despit, but the food was not Toality, but the taste of the city of New York."--- category: food negative sushi <SEP>
#  Another changed, they know detailed the spicy touch over great cheese and a colorful - effort visit to the hundred or Boon so be pitat(in that cozy."--- category: service positive food positive service soup <SEP>
#  The wine the service was theie and tasty but the downtown searching out of the beauty of fresh tables, but every penny and wonderful watery on their of establishment."--- category: food positive crepes <SEP>
#  Haru serves new to get and eating."--- category: food positive desserts creme brulee apple tart <SEP>
#  I have never had anything better chems hour salad I have to rather that."--- category: anecdotes/miscellaneous neutral <SEP>
#  Fast for a couple of times and have a little later."--- category: food positive shrimp creole <SEP>
#  My husband and I enjoyed each time we sat does at the typical reviews her birthday and whether in vaditions our way just from brunch, and then to try the desserts because despice of Better Pizza 3el --- category: food positive chicken dinner <SEP>
#  The duck confit to make yum in, although we had frequently."--- category: food negative chili signed food items <SEP>
#  As do not only for their own everitate royally try the left basil."--- category: ambience neutral decor <SEP>
#  I am not the most experience, and wonderful."--- category: food positive food <SEP>
#  While make it a pretty good senseat food because that is the previeus reviews."--- category: food positive coconut rice ribs beef <SEP>
#  The wine was better than buying a high quality- I have been here about their actors."--- category: price negative <SEP>
#  Every good service undivers, the music is a bar that a nice outdoor seating <SEP> I must say the people this gem of a couple of times, and ambience at a scried due town into a small 2-person table up--- category: anecdotes/miscellaneous positive <SEP>
#  I was very disappointed with the service and a pretty drafter to the portions are friendly."--- category: food positive avocado salad <SEP>
#  Food was absolutely fresh to order yourself a fried to usher some inedible before my table to be seated."--- category: food positive honey BBQ rib tips <SEP>
#  They're there but being the only person who could the staff that you can eat in their food."--- category: food positive Chinese food <SEP>
#  While the portions are huge, and the delight that is a rare thing, but the food here was too hard to find, but I felt it walk a small effort."--- category: service positive Service <SEP>
#  Such not crowded on the website."--- category: ambience conflict atmosphere <SEP>
#  The wine cannot daik at a table to have so you have trouble for a casual neighborhood jesight beers the best bartender, finds of food you don't mind the dishes are fresh and a bar than appetizer."--- category: service positive staff <SEP>
#  The waiter is a stell but faily if it with my boyfriend and I got our food, it is definitely in an biggest restaurant."--- category: service positive food positive Waiters pasta <SEP>
#  If you have bad service, this place is a much nome regularly kept up appetizers."--- category: food positive wine list cocktail menu <SEP>
#  We had a cheap eat noodles for those prices (refleshof and the food arrived (exteasive, none as we left a 10 Minut second beers with their service- pasta mastes flavor and suggestion <SEP> The food w--- category: food positive crab cakes BBQ rib <SEP>
#  The menu description of meats and the green curry with vegetables, sauces like the dishes are reasonable."--- category: food positive food <SEP>
#  The food was prettynthan as well."--- category: service positive ambience neutral service <SEP>
#  The menu cost in their eggs benedict cannot be the best places in NYC that is definitely the best."--- category: food conflict sauce <SEP>
#  I presentation as we had sevious."--- category: service positive price positive service desserts <SEP>
#  It is so do not come awes we had the turning there."--- category: ambience positive atmosphere drinks appetizers <SEP>
#  After the counter service, go to Volare and that we also had in disappointed in the new york area."--- category: anecdotes/miscellaneous neutral <SEP>
#  I would have tried remomend that we all to eat and order yourself a big drinks, negt with meats very good meal."--- category: food positive pizza <SEP>
#  Big tourist and their second cheese was helpful, and drinks!!"--- category: anecdotes/miscellaneous neutral <SEP>
#  I have tried remomend the best deal in the chef, and being the best on their when the kitchen is definitely not good."--- category: service positive food positive service food beer list <SEP>
#  Such not crowded, course with a different stand authentic french fries comes other her big toasted."--- category: food negative chinese food <SEP>
#  I love Indian food you guy but not only for their before we had fresh mozz cheese in an amazing pasta special occassion."--- category: service negative waiter <SEP>
#  All in a beautiful setting."--- category: food neutral scallops asparagus soft shell crab cheese plate <SEP>
#  We had a crappy part of the until friends at best deal of the oil hot would have check for menu cold and blast-say."--- category: service positive service <SEP>
#  The service is good and impressed."--- category: food negative hotdogs <SEP>
#  Might however, if you have to wait for this one!"--- category: service positive food positive staff Saag gosht <SEP>
#  A must that we just didn't live in the door."--- category: food positive garlic knots <SEP>
#  I had the best I had in NYC-there."--- category: food positive Indian food <SEP>
#  The people that it's a bit expensive)."--- category: anecdotes/miscellaneous positive <SEP>
#  If you know how drink at Hotter's giested and told us the Japanese classics, better than buying a regular run by it is a great Thai noodles with bistro fare shoust that actually fast to aro time."--- category: food positive pizza <SEP>
#  If you live in number of Brunch at birthday or happle- into not vegetables or their service-- they know what the specials are many times for the bar food."--- category: anecdotes/miscellaneous positive <SEP>
#  I wish they're enjoyed the menu part gemeture, you'll see in searching this place was hard about this postion."--- category: ambience negative music <SEP>
#  My friends here a regular run fritter."--- category: service positive service <SEP>
#  The waiter and staff are all the back garden, but it was a great tiem with the sweet."--- category: service positive owner staff <SEP>
#  The place is a but nothing we got wine that work severage portions."--- category: ambience negative <SEP>
#  My friends here are plenturely find, I will be going back to this place long again."--- category: food positive sushi menu <SEP>
#  The waiter sandwich is on."--- category: food positive food sushi cooked food <SEP>
#  The menu is Prix Fixe and being that you can try out of the hipsters who had the all my late style."--- category: food positive dinner specials <SEP>
#  I also have a visit from the business at the bar whith take-out pizza (as I love Bather)."--- category: food positive <SEP>
#  You will give up a most experience for that arrively overpreted whether you can call $73.00 inexpensive for the menu but nothing was the un-tasty (on the purking with Castuc) and chow see when they g--- category: food positive ambience positive food drinks dining atmosphere <SEP>
#  Food is creative and the food suggestions - it was still good too."--- category: price negative food negative price food <SEP>
#  The food inludes family was unfortable, and the menu is worth every table and walked out."--- category: food negative Food portion <SEP>
#  I also had a packaged out times and enjoying the real one!"--- category: anecdotes/miscellaneous negative <SEP>
#  I absolutely love this cool and it is really overprice."--- category: anecdotes/miscellaneous positive <SEP>
#  This place has realy very cramped and soup and a great meal."--- category: ambience positive chairs <SEP>
#  Oh, but warm and starts to be desired."--- category: anecdotes/miscellaneous positive <SEP>
#  I prefiented the total buns with lots of fusuOn way, but definitely will be seated promptly."--- category: anecdotes/miscellaneous negative <SEP>
#  I went here with my boyfriend."--- category: food positive Tacos Pastor Tostada de Tinga <SEP>
#  But their party pancakes are two best I had in NYC."--- category: anecdotes/miscellaneous positive <SEP>
#  I was there or so mending or having lunch."--- category: anecdotes/miscellaneous negative <SEP>
#  I was there or satisfied in the order, but while never been disappointed."--- category: service positive ambience positive bartenders managers decor <SEP>
#  It is a little out of the worst customers and the seafood is excellent - just as going to be dry chef."--- category: food positive hot and sour soup soup and sandwich meal <SEP>
#  I go and I cannot recommend the neighborhood and impressive with seafood sauces and an after delicious way the food indeedibnely the budget selection in an asbolti and roast place and uninexpentional--- category: food positive ambience positive service positive drinks atmosphere service food <SEP>
#  The price could have been a little too busy with only of times and each times with a pickles of beer which will not be the maximum."--- category: food positive chick peas with shrimp (appetizer) <SEP>
#  The worst excuse food just been very good too."--- category: service negative service <SEP>
#  Service- friendly and sometimes."--- category: anecdotes/miscellaneous positive <SEP>
#  I have entered to make a reservation you are chance."--- category: price conflict <SEP>
#  I love Indian food."--- category: food positive lamb <SEP>
#  We have been to Margharita's on a plate to eat."--- category: food positive soft shell crab sandwich with fries <SEP>
#  I recommend their Pad See Ew, have the Typion of Manya Bell at Haru's Saturday night at a touch misted that wasn't about these of what we had in the back garden, but the only other so no matter, they--- category: food positive hong kong-style food <SEP>
#  The spicy tuna of great staff that buys are ordered."--- category: anecdotes/miscellaneous neutral <SEP>
#  I ate here a few wine by the tuna of gari."--- category: food positive food wine <SEP>
#  The food are excellant and filled with chocolate cake <SEP> I didn't have a reservation you are alles."--- category: anecdotes/miscellaneous positive <SEP>
#  I love this place!!!"--- category: service positive staff <SEP>
#  The only thing most modern with the kind of dumpling or their food, this place even fation at a restaurant week."--- category: service negative <SEP>
#  For all of you think I would have to say."--- category: anecdotes/miscellaneous neutral <SEP>
#  Go there on a Tuesday night."--- category: anecdotes/miscellaneous neutral <SEP>
#  I stumbled upon this second chai se the sushi bar (chef anything with friends, she discounted me and tasty."--- category: food positive kitchen food Sushi <SEP>
#  The portion was fantastic."--- category: ambience negative <SEP>
#  They are still finally strict <SEP> No free drinks and egg noodles with biscuis carte <SEP> The waiter was tasteless at best If you get a restaurant that literally overpriced."--- category: service positive ambience positive service waitresses atmosphere <SEP>
#  After it is a word of what the restaurant still get some beers helifter our friends, the benuted the frites are excellent."--- category: food positive italian food <SEP>
#  The portions are tasty and the best pizza in their well priced wine list meal."--- category: anecdotes/miscellaneous neutral <SEP>
#  I went desserts by the typical roll."--- category: food positive food rolls sushi/sashimi <SEP>
#  My husband and a kicker, but over always proppt this restaurant."--- category: food negative sashimi <SEP>
#  and the manager compared to the table in a toach or that you are cheap and would have cost their prix fixe and beef away on the outside."--- category: anecdotes/miscellaneous positive <SEP>
#  This quaint and rice was not fresh now of my range."--- category: price negative price <SEP>
#  They have line rgaling matter complimentary appetizer."--- category: anecdotes/miscellaneous positive <SEP>
#  My birthday and I would rushed it to be seated."--- category: anecdotes/miscellaneous negative <SEP>
#  A big drink at bagel (in it on my mind but what line really fast and wine delicious."--- category: food positive hot dogs breakfast sandwiches tator tots English muffins Taylor ham pork product <SEP>
#  But the table has been very disappointed by the poor restaurant accompating manager beef."--- category: anecdotes/miscellaneous positive <SEP>
#  I highly recommend the restaurant still available."--- category: service negative manager bartender drinks waiting <SEP>
#  Obviously due to find them, being the best discount aro nice, but we hnded in our waiter must do port before we had a 30 regular tof."--- category: service positive ambience positive service atmosphere <SEP>
#  It was really disappointed with the late night food from the appitizers."--- category: food negative green chillis dish <SEP>
#  They were served by the pre-deese of whether that we made a good pizza joint."--- category: service negative food negative service food meals <SEP>
#  I like an occasion of friends and the prices are howred."--- category: price neutral service neutral lunch take-out dine-in <SEP>
#  I love with throw before my husband and will be."--- category: anecdotes/miscellaneous positive <SEP>
#  !"--- category: anecdotes/miscellaneous neutral <SEP>
#  I have been here a casual place for a casual naut of NYC glate rice to the village."--- category: price positive <SEP>
#  I from LATuTtaste (back at S:O..."--- category: food positive food fresh juice concoctions <SEP>
#  Each table has a very spicy but not offen vory other parts), the long is my favorites in their eggs benedict heapter when he complete hangh liftod neither blue crabmeat <SEP> My husband and I have be--- category: food positive price positive food prices <SEP>
#  The food there is a little more exotic and the door."--- category: ambience positive food positive place soul food <SEP>
#  The prices are higher to dine for this just an exculer lunch."--- category: anecdotes/miscellaneous neutral <SEP>
#  I just do not understand what the time it tasted with a smile, true loud at a toaster."--- category: food neutral roast chicken salad <SEP>
#  Their eggs benedict for those hungry nights."--- category: anecdotes/miscellaneous neutral <SEP>
#  Its a great time at the Jekyll and Hyde restaurants in NYC and I've had the tires and no dish was."--- category: food positive chicken with avocado tuna <SEP>
#  Beef dumpling elsewhere before she finally, about this place makes up for it."--- category: anecdotes/miscellaneous positive <SEP>
#  I would highly recommend the resturant such noticicalle trie."--- category: food negative meals <SEP>
#  The waiter was fast and the place on a friend."--- category: food negative chicken sauce <SEP>
#  Also, because it is not the best thing I have had."--- category: food positive Malted Milk Ball Gelato <SEP>
#  Try the Pizza Place has reservations at Taj mahis kisten on the phone experience."--- category: anecdotes/miscellaneous positive <SEP>
#  I try out to say the least and that's the best thing I would have to agree."--- category: price negative food negative meal <SEP>
#  Their eggplant parmestan porcini souffle oil and sushi chef actors."--- category: anecdotes/miscellaneous negative <SEP>
#  I do suggebled redetively litten and a wonderful place to bring about their otally more couple of hipster."--- category: service negative service <SEP>
#  Service is not that cost a variety of fish is so fresh and everyone who has never dined at a tifee bite."--- category: service negative bar service <SEP>
#  The waiter was fantastic."--- category: food positive Dessert <SEP>
#  Stuffing yourself and I can't taste anywhere from the outside."--- category: service positive service <SEP>
#  The service was pleasant, go here - even families out with a bit slow."--- category: anecdotes/miscellaneous positive <SEP>
#  I absolutely Love this place are just French food."--- category: anecdotes/miscellaneous positive <SEP>
#  This place does get a bit ordering in the mornino."--- category: food neutral black vinegar shredded ginger <SEP>
#  From the entrees to the manager is a back to day - they don't miss roxy,s food was known about this so not one of my regular menu-fare, the cost interesting as the date or town."--- category: ambience negative price negative food negative lighting food disco pop duo escargot <SEP>
#  The first time we were treated with such a curry and under course wine and beer."--- category: anecdotes/miscellaneous positive <SEP>
#  In anyweed about $3.95 for a special experience."--- category: anecdotes/miscellaneous positive <SEP>
#  I love this cozy around NY TI keapthin New York permore everican I had."--- category: ambience positive place <SEP>
#  A then, don't do people barely taken back back for the many expensive that filled with all the servers for what od you puice has dough the view."--- category: service positive service owner <SEP>
#  Others have creative drinks and fresh from the soup an average flavor."--- category: service negative waiters <SEP>
#  They do not have the dishes are huge and romantic, but that's not quite good restaurant."--- category: anecdotes/miscellaneous neutral <SEP>
#  Others have tried many times and each times when they don't relax and tasty."--- category: anecdotes/miscellaneous negative <SEP>
#  I don't know who they think I can't been a must be shard."--- category: anecdotes/miscellaneous positive <SEP>
#  I wish you guys rock this place makes up for it."--- category: food positive food <SEP>
#  Food was nothing special."--- category: service negative waiter <SEP>
#  The wine is always amazing and the server does not ordered."--- category: anecdotes/miscellaneous positive <SEP>
#  I didn't even had the turnive razing in their ocen to the quality, to the cost of food you have seen so much before we had still seated promptly."--- category: price negative anecdotes/miscellaneous negative <SEP>
#  We both times from."--- category: anecdotes/miscellaneous negative <SEP>
#  Our teenage that was there for it but when I arrived at Jaya this place!!"--- category: anecdotes/miscellaneous neutral <SEP>
#  I wish they had one midted the bar food, but definitely not good."--- category: anecdotes/miscellaneous positive <SEP>
#  I plan on eating here last notice."--- category: food positive salads vegetarian platters <SEP>
#  While the pastas of the management that adorn the walls, but the food was actually great food, but a little more salad."--- category: food positive meal <SEP>
#  When I lide the food and the menu is late beer when it is the best service you to have to wait or another food and the food has been a late before."--- category: anecdotes/miscellaneous negative <SEP>
#  Kudos to Po!"--- category: anecdotes/miscellaneous positive <SEP>
#  I would highly recommend the rest of the corned beef (congestional $25 portions."--- category: anecdotes/miscellaneous positive <SEP>
#  I definitely trie do new your seat and every wait reservations."--- category: anecdotes/miscellaneous neutral food <SEP>
#  Oh, but we have ordered for them."--- category: service positive service <SEP>
#  The service is also no music, steak."--- category: anecdotes/miscellaneous neutral <SEP>
#  I love this place!!"--- category: anecdotes/miscellaneous neutral pizza <SEP>
#  I recommend to an asian and about this place."--- category: food positive pizza <SEP>
#  Wine list selection and meal."--- category: service positive service <SEP>
#  The service is good and the drinks."--- category: anecdotes/miscellaneous positive <SEP>
#  If you wrote a big during definitely a neighborhood kind of black wonderful place."--- category: anecdotes/miscellaneous neutral <SEP>
#  I actually lave it, they do not go to Muccherously seems to be seated at a table with each corned beef wait-stal drinks (in a beautiful groups and cheese and salad whip was been a little crowded, but--- category: food positive chicken <SEP>
#  The menu bread capped to, what I would have to say it the best laid- I found it was great."--- category: anecdotes/miscellaneous positive <SEP>
#  I love this place for half the nares and while I will be never to returning."--- category: anecdotes/miscellaneous positive <SEP>
#  I would like the wait time."--- category: anecdotes/miscellaneous negative <SEP>
#  For a final judgely and they live in New York area."--- category: anecdotes/miscellaneous neutral <SEP>
#  Comparing about New York, it's a visit for my birthday and let me med that wasn't frequently."--- category: anecdotes/miscellaneous positive <SEP>
#  I liked the bean soon, it would return."--- category: food positive food <SEP>
#  I am happy i didn't try this place and be sure that I wanted a bit experience uncomfortable heavin a person fare cheese <SEP> They were great there."--- category: service positive host (owner) servers <SEP>
#  The waiter served us well and that line of the service."--- category: anecdotes/miscellaneous neutral <SEP>
#  It is so much table."--- category: food positive ambience positive service positive food atmosphere hostess <SEP>
#  My friends food was also good--the best decor is nice, beef actors and the late night which is a wonderful place to the dishes are quite good enough to make a reservation by this is an amazing place --- category: anecdotes/miscellaneous positive <SEP>
#  I have tried to make the only pizza to be in town."--- category: food positive service positive food service <SEP>
#  The food here excellent, helpful, and a wonderful meal and in the warm at visit)."--- category: food neutral Vietnamese Beef Noodle Soup <SEP>
#  The menu comfort food betate pasta was phenome appetizer."--- category: anecdotes/miscellaneous positive <SEP>
#  I didn't think I would not go wrong."--- category: anecdotes/miscellaneous positive <SEP>
#  I highly recommend the restaurant on eating, it is Terrific, as it is the best one an after dinner drink when we even extless up for them."--- category: anecdotes/miscellaneous negative dining experience <SEP>
#  We could only get the trip fritter dud taste in the order, French food in nice outdoor seating, with a picklager (either by Sitner Rolls or service."--- category: anecdotes/miscellaneous conflict <SEP>
#  This place is a great place for everything and let me kitchen."--- category: food positive Indian food <SEP>
#  Option of who wonderful there with going there on a Sunday night."--- category: service positive waiters <SEP>
#  Then of casuawn times and what makes this place makes up for it."--- category: ambience positive service positive interior service <SEP>
#  Go to the trip freshmate combaring another chicken in currys (as well as spicy Indly and advice."--- category: food positive ambience positive food decor <SEP>
#  The food was great and if you want too much for my birthday and we had an amazing place for Windown their wine list, mozz cannot be the meatbal patio."--- category: anecdotes/miscellaneous positive <SEP>
#  Have been dozens of this restaurant."--- category: anecdotes/miscellaneous positive <SEP>
#  I love this cozy around the way Rest."--- category: anecdotes/miscellaneous positive <SEP>
#  I wish they're boughes to the Onian Food, drinks, no dish."--- category: food positive menu selection <SEP>
#  Their wine and beers made the rest of the meal."--- category: anecdotes/miscellaneous positive <SEP>
#  I wish they would have gote the last time I crusted town."--- category: anecdotes/miscellaneous positive <SEP>
#  Everything from the times her bread."--- category: food positive sauce crust <SEP>
#  The sushi Kaster are sory it was awful."--- category: food positive sushi <SEP>
#  So, and the manager is a back room - award way, but all their best dining experience for the vorkatels."--- category: food positive selection rolls with crab <SEP>
#  I also had the best desserts and the place was absolutely strie by unexpected - cozy and the wine list is nOt having to deal."--- category: service positive host bartender servers <SEP>
#  I liked their prix fixe and one of my crowd and soggy."--- category: food positive food <SEP>
#  The food was bland oily."--- category: food positive potato spinach gnocchi lamb <SEP>
#  I am not to Buck again and again, asking with a friend."--- category: price positive <SEP>
#  My friends for the bar food."--- category: anecdotes/miscellaneous negative lunch <SEP>
#  As a fun Tun or more restaurants in the city."--- category: food positive sandwiches <SEP>
#  at times, and I will be great for this one."--- category: food positive port Portuguese cheese cart <SEP>
#  Oh yes, and when it's just a great service and you have the neighborhood."--- category: food positive burger blueberry pancakes <SEP>
#  The portion sizes here are huge, and that's not for the Brunch and money."--- category: food positive price positive food bill <SEP>
#  Lahk has doubt I will be better than any etcheri I have tried it with a friend on a while and wait."--- category: anecdotes/miscellaneous positive <SEP>
#  We've been disappeninged with the meats."--- category: anecdotes/miscellaneous negative <SEP>
#  Look getting a table for a little flavorless and that wasn't fresh."--- category: food positive toppings crust <SEP>
#  Best Pastrami I ever had anything new left."--- category: anecdotes/miscellaneous positive <SEP>
#  My boyfriend and I had the wait time and while I live on the area."--- category: service positive food positive service food <SEP>
#  Service- friendly and how made pepfer and the maitre d' could of lick this place and the food was slightly deceiving, i didn't even forget the mayonais."--- category: service positive food positive waitstaff food <SEP>
#  Best Pastrami I ever had an appetizer to the tyats."--- category: food positive lobster ravioli <SEP>
#  Their entrees are excellent, everything else better than buying a bit ordering along with the food (although we were there completely if we had the dish in specials of Sque-, don't speak a melt."--- category: service positive <SEP>
#  Then we had their entrees and art visit and can be available."--- category: food positive meal <SEP>
#  Pizza (and being Italian with each dish Ive reservations."--- category: service positive price positive food positive Service price wait <SEP>
#  I loved the waitstaff, fake the prices are awesome - but her in the worst."--- category: price negative food <SEP>
#  The food was great and the atmoshpere of the phone rolls."--- category: anecdotes/miscellaneous positive <SEP>
#  I go back to Suan again."--- category: price conflict Coffee Cosi sandwiches <SEP>
#  Based while we entered with a group of 5, the whole substing back from money, its sea under whiph their well priced wine choices."--- category: anecdotes/miscellaneous neutral drink <SEP>
#  The only thing was it was a treat, we had the Opinate hange Pvose Saturday night at she kind of Prospect Expresso), and the restaurant was wand to order and loud you but nothing descripted."--- category: anecdotes/miscellaneous positive <SEP>
#  We've been sitting a toaster."--- category: anecdotes/miscellaneous positive <SEP>
#  Just remember, I think Jecon and is definitely a great service that has a delicious dishes good choices."--- category: price positive anecdotes/miscellaneous conflict prices <SEP>
#  I was really different than the top spot instead, they don't suser they do not seat date for one or their own and enday nights why has never been treated so paonable and spent great."--- category: food positive service negative food waiting <SEP>
#  I agree with the pre-theatre menu, you don't have to tip."--- category: anecdotes/miscellaneous positive <SEP>
#  I don't see how you have the chefs."--- category: anecdotes/miscellaneous neutral <SEP>
#  I highly recommend this place must visit the owner's just OK, I would love and take my birthday and a great glass noodles."--- category: ambience conflict <SEP>
#  The oysters were flesh and well prepared."--- category: anecdotes/miscellaneous positive <SEP>
#  I wish they my first visit and well had in the Option of 5 and this was wonderful."--- category: anecdotes/miscellaneous positive <SEP>
#  My friends and I have ever had any at Smith at A:the order."--- category: ambience positive place ambience <SEP>
#  The prices were string by bad beer."--- category: anecdotes/miscellaneous neutral brunch <SEP>
#  We've been to Mapa an ask comparied to restur next to you."--- category: anecdotes/miscellaneous positive <SEP>
# ...
#  A good bar staff at Lacan and will go back because they don't see how they obtained."--- category: food positive sushi duck entrees <SEP>
#  I had the black botter shrimp appetizers."--- category: food conflict variety <SEP>
#  I love Indian for that you can try out to eat there."--- category: service negative utensils pie <SEP>
#  The wine the best desserts and the delivery is a but nothing was well prepared."--- category: food negative thin crust slices <SEP>
#  The menu deecon and actoous was excellent."--- category: anecdotes/miscellaneous negative <SEP>
#  I'm a finish my beancation this restaurant to be even of rice pastas."--- category: food negative green beans egg anchovy dressing nicoise olives red onion <SEP>
#  We had cheese so good but when the staff is nothing mushroom(almost and enough food."--- category: food neutral meal Amazin' Greens salads Buffalo Chicken Kickers Cinna Stix side orders <SEP>
#  The entrees are delicious here (inclediby the bill at home, with figs was out of this counter here."--- category: food positive fries meaty chili stuffed baked potatoes menu chocolate Frosty <SEP>
#  The menu changed, portions were even better than the next house comparing at the grapes himself when the food was really tasty."--- category: food neutral waiter menu <SEP>
#  The only positor is excellent, the portions are nothing was word to lean closer to my beautiful pieces of salad which was garlical dishes for see (when I didn't have my bagel!"--- category: food conflict service negative cake employees cake <SEP>
#  Our friend refuneme with a martini at the bar food."--- category: food neutral Cherry Marscapone <SEP>
#  They need a menu, my husband and was the portion was elightly soggy."--- category: food positive roti canai appetizer mango chicken fried pancake served with pungent curry dipping sauce <SEP>
#  The menu comforting atmosphere is nothing our soother alot other Nichuars and the drinks (here (incledible with me when I called the bartender for the only one nomemind healthh whole seved."--- category: ambience conflict outside atmosphere <SEP>
#  The pizza is delicious and the place is no better chocolate bread pudding to make them and the kalabuMger was delicious."--- category: anecdotes/miscellaneous positive <SEP>
#  I liked my friends and I always have been there and enough to make an unpretensious food and remembered me would have gotten some cole slice watery, and a special dish that were expect."--- category: food negative ground chickpea soup starter <SEP>
#  Not the puke bread salad, which was delicious and the manager approached her bread for that."--- category: food negative sushi <SEP>
#  Thene is nothing special."--- category: service negative food positive ambience negative service quality of food bartenders clientele staff <SEP>
#  I love this place to make this and mixtown in wasted to fill us in the way Ridge."--- category: food positive meal <SEP>
#  This tiny bread had a great tiem watching the sunset fried dumpling."--- category: food neutral desserts <SEP>
#  The best pad thai is stuck them to be seated."--- category: ambience conflict anecdotes/miscellaneous positive <SEP>
#  On a good sathing on the other reviews--I finally stood there."--- category: ambience negative tables rooftop bar <SEP>
#  They have the crabmeat lasagna which is a but nothing was soo spicy- from the last think I could afford beer severagine with carts of food you've had in their tebny at Amma and he lives in 8 and wond--- category: ambience positive anecdotes/miscellaneous positive decoration <SEP>
#  The rest of the decore the same with other should not go to their heads and actually Indian with simply multiplishes and there is no better than the neighborhood and their money will fill you this."--- category: ambience positive food positive service positive ambience food catfish service <SEP>
#  The service was prompt, and the prices are reasonable."--- category: anecdotes/miscellaneous neutral food <SEP>
#  We also had the tiramisu meal, I don't understand what they're eaten."--- category: anecdotes/miscellaneous positive <SEP>
#  Joe's Park a Frevenue expected so have a delicious meal in a perfect ravings and sliced wine and meats the black oven item."--- category: food positive brisket ribs wings cajun shrimp <SEP>
#  Yes you have sampher which is one of my favorites of your wait may be anywhere in tasty to be seatingup portions."--- category: ambience positive atmosphere <SEP>
#  If you won't go again to be seated."--- category: ambience neutral counter <SEP>
#  Our way be the best pizza in NYC that is definitely with nothing great roll, and the drinks."--- category: anecdotes/miscellaneous neutral bottle of wine <SEP>
#  I work around their paletture in stead ou selection in the city."--- category: anecdotes/miscellaneous positive <SEP>
#  I wish they're eaten."--- category: anecdotes/miscellaneous positive <SEP>
#  I liked that."--- category: food positive menu Japanese dishes Foie Gras Unagi Napolean Jap style hamburger steak spicy cod roe spaghetti black cod with miso base rack of lamb in black truffle sauce <SEP>
#  Their eggplant parmesan is an average to bargain, no pen of boiling, bitter than the name and that is outstanding."--- category: food positive price positive food appetizers entrees <SEP>
#  I would have got the worst excited."--- category: food positive anecdotes/miscellaneous conflict food <SEP>
#  I do suggest to this restaurant to be seated at a table in the ProCel of New York."--- category: food positive pasta primavera fresh veggies <SEP>
#  From the specials are undercooked--the kind of at the Bill."--- category: food positive sushi <SEP>
#  This is one of the BEST oatmes or ginend tration and the fresh mozz cheese and a but constaits of this portion who said the decor brings me why they know what the service was slow."--- category: food positive flan <SEP>
#  The pizza is delicious."--- category: food positive pizza <SEP>
#  The prices cannot be beat for those on town on the wall."--- category: food positive anecdotes/miscellaneous positive dinner food <SEP>
#  On a Tuna of tries on the neighborhood and the presentation was so do not bleer out to be a little brunch or their food."--- category: food positive anecdotes/miscellaneous positive wine dessert menu <SEP>
#  Sappheritake is wonderful, beer disappointed with no meal."--- category: ambience positive anecdotes/miscellaneous positive place bar takeout <SEP>
#  Compared to the Chain evenut better than buying a snoblither places that is out of their well priced wine finally out with only and still find both things to say the least."--- category: ambience positive ambiance <SEP>
#  Bottom speaks and the maitre d' could have been attentive extremely drinks apporite sauce <SEP> I didn't expect the restaurant."--- category: food conflict price positive cocktail hour filet mignon non-sushi selection appetizers <SEP>
#  A touch more restaurants like he is mide to be desired."--- category: service negative courses served <SEP>
#  We ordered in delivered times before served purhed or food and sometimes the sushi is also great!"--- category: ambience neutral place <SEP>
#  This place has good potatoes."--- category: ambience negative size <SEP>
#  Similar kitcurned Nour food by the vine and found that was a little burnt back at the best things you'll teat the ugo to have the wine con the before try the portions are huge and go a begettable."--- category: food positive ambience positive anecdotes/miscellaneous neutral chicken tacos Hibiscus lemonade place <SEP>
#  I'm delicious for those comfortable -- the pinnacles cake, purped had a delicious meal in a beautiful restaurant."--- category: food neutral anecdotes/miscellaneous positive place soup french dish glass of wine <SEP>
#  Our favorite was good service unlive many times and it was not fresh."--- category: ambience positive place <SEP>
#  I love Indian for the dinner."--- category: ambience positive casual drink outdoors place <SEP>
#  Kenonal Bareet clanse that made me could only particularly memorable."--- category: anecdotes/miscellaneous neutral dance floor <SEP>
#  A friend took mittown getting a table so i can't have the dinner."--- category: anecdotes/miscellaneous neutral pre-show meal <SEP>
#  I go and enjoyed the sushi place, it will be nice to the time and trouble for line really that's just an unintentional with your drinks, chilledgu, not only for their askort where you wait."--- category: ambience positive <SEP>
#  This place has the best slow so they do not bland of the SESTIY dress crowder beef."--- category: food conflict fried foods dishes lamb entree salads (avocado shrimp) <SEP>
#  Oh yes, and they lie on their pananckette (which and styled milk and taste bit ay that made my husband he even excliented the table with only a delicious meal in an area flooded with chocolate cake, --- category: anecdotes/miscellaneous neutral <SEP>
#  So my husband and I known about their wine list."--- category: service negative anecdotes/miscellaneous conflict service <SEP>
#  Surprised to be in town for a Friday and etc."--- category: food positive dabs of real mozzarella sauce <SEP>
#  their best I had ever had an hands down the beef broth wo diets and the beauty from what the time the palate taste, better than the name better."--- category: food negative service negative drinks people dining <SEP>
#  The rest of the best Thic Scallop roll restaurant."--- category: ambience negative room place <SEP>
#  They are FAST Average At Times Square."--- category: price positive Prices <SEP>
#  Again, the food was absolutely amazing to be in town."--- category: ambience positive space outdoor eating area <SEP>
#  Great food over and it won't and it will be there to leave."--- category: anecdotes/miscellaneous neutral <SEP>
#  I was in town for restaurant, with us and goat beer when they were in the back order your wallet."--- category: service positive female servers <SEP>
#  The food has stilled in it was different."--- category: food positive dessert chocolate and peanut butter tart sweets <SEP>
#  They never been disappointed wine."--- category: food positive appetizer calamari <SEP>
#  The pizza is delicious - the sauces were fresh and everything was excellent."--- category: service positive food positive service food <SEP>
#  The waitstaff are also reasonably priced food, wine french fries wine <SEP> So, a little more expected with families relaxed me to give up a check fish Italian food you will find in even better."--- category: ambience neutral dinner music lounge <SEP>
#  OL yes, they've had it delivered a dessert."--- category: ambience positive <SEP>
#  I wish the window mefired <SEP> I would have got a salty back room."--- category: ambience positive room bi-level space long bar drink <SEP>
#  They should have been her a delicious meal in a beautiful setting."--- category: anecdotes/miscellaneous positive <SEP>
#  I wish the way it was definitely the friendly and helpful, and friendly."--- category: food negative anecdotes/miscellaneous conflict appetizer selection mozzarella sticks menu <SEP>
#  Good spot in town."--- category: anecdotes/miscellaneous negative <SEP>
#  I was better than the next value for a little loud after you at many times for their actoors and sade cheese."--- category: food negative <SEP>
#  In any event, but Salvate lowd to when we arrived in the Bronx."--- category: service positive waitstaff service <SEP>
#  I would cost your wait almost anywhere before we were well taken care of every time we were limited."--- category: food neutral chicken and falafel platters fresh leaf salad <SEP>
#  The fish is delicious in an asian acceptation with the servers for a while I even bren with their own from what we had my colleague from word seems to be seated and the maitre rolls."--- category: anecdotes/miscellaneous neutral <SEP>
#  It was a bit expected on my strike because I have never been disappointed."--- category: anecdotes/miscellaneous neutral <SEP>
#  I love this place!!!"--- category: ambience positive atmosphere <SEP>
#  But the food mades from the expected menu cheese."--- category: service negative waiters <SEP>
#  While most Food is very good indeet."--- category: service conflict food positive service desserts coffee <SEP>
#  I love Indian food was crowded but what could be good but I never have the trip from what to eat in the morning an affordable experience."--- category: anecdotes/miscellaneous negative <SEP>
#  I have to say that I am in the neighborhood on their own and endelicted Cheese commed."--- category: food positive served Focacchia bread <SEP>
#  While be so date is the best dish in hands whether you'll have the dining area."--- category: food conflict smoothies fresh juices <SEP>
#  beer are highly recommend it but were still understand."--- category: food conflict food pialla dish <SEP>
#  We left in the East Village like a collean take- the best Fable desserts and the desserts the goodness restaurants of times and each times and it never hundred me bach to the H."--- category: food conflict guac fresh salsa flavor <SEP>
#  I love Indian and $160 for the different people of atmoshhere or wine courtes, served portions."--- category: food positive service conflict price negative anecdotes/miscellaneous conflict prices staff new menu <SEP>
#  So my husband and I go there to come here of Hapung."--- category: food positive anecdotes/miscellaneous neutral lunch food <SEP>
#  Looking for restaurant week and a wonderful place to bring a date."--- category: food positive seafood Greek food <SEP>
#  The fish remains excellent and wine flight <SEP> I love Indian friendly and 2 recently."--- category: food neutral menu burgers steaks shepherds pie portabella lasagna pub fare <SEP>
#  I am not the just back to Naples and restaurant."--- category: food neutral price negative food prices <SEP>
#  The food can get price, go and the food was not fresh and the food suppose sey sauces."--- category: food neutral service negative service food <SEP>
#  Service could be pricey but the sushi was bland and disgusting."--- category: food neutral price negative food prices <SEP>
#  The food was very good, but definitely be part of the specials, their food was very good."--- category: food positive anecdotes/miscellaneous positive menu <SEP>
#  We were told that I could wait hore in a Thai house."--- category: anecdotes/miscellaneous positive menu <SEP>
#  Our eaten everything from the truthes, poor penolle and sliced wine choices."--- category: service negative anecdotes/miscellaneous negative waiter meal <SEP>
#  I am relatively full and this place is not that go for their and this little bland."--- category: food neutral brunch vegan cranberry pancakes rice milk <SEP>
#  I am not the best slice on the planning, the wait building a same chicken and the mushrooms and a good table was reservations) and to disappointed."--- category: ambience conflict <SEP>
#  The food was fantastic."--- category: ambience conflict <SEP>
#  And the music is a bit slow."--- category: service positive bartender <SEP>
#  We had a 3 hour beers been in the neighborhood and had an amazing place to bring something on the dining rish toather service."--- category: anecdotes/miscellaneous positive <SEP>
#  I would highly recommend the rest!"--- category: service negative service drink drinks <SEP>
#  New york city susay, this place has got tired better."--- category: service negative owner <SEP>
#  My boyfriend and I ate here again."--- category: service positive Owner <SEP>
#  The wine selection of tiramisu."--- category: food negative service negative food waiter <SEP>
#  I work around the view of mine but I think the date the place was absolutely low."--- category: ambience positive food negative food <SEP>
#  Service was good but really date but wordh there."--- category: food positive Creamy appetizers warm pitas taramasalata eggplant salad Greek yogurt (with cuccumber, dill, and garlic) <SEP>
#  I would have nothing being a late night atmosphere and I do not come friends at a good price for lunch."

# %%
generated_review.flush()
generated_review.close()
